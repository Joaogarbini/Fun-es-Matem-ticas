# %% [markdown]
# # Elementos de Algebra Linear  - Ron Larson Cengage Learning
#
#
#
#
# O objetivo desse estudo é de resolver alguns exemplos e exercícios do livro do Larson utilizando a linguagem Python
#
#
# https://www.amazon.com.br/Elementos-%C3%81lgebra-Linear-Ron-Larson/dp/8522127220/ref=asc_df_8522127220/?tag=googleshopp00-20&linkCode=df0&hvadid=379707181411&hvpos=&hvnetw=g&hvrand=14510418304098405183&hvpone=&hvptwo=&hvqmt=&hvdev=c&hvdvcmdl=&hvlocint=&hvlocphy=1032065&hvtargid=pla-809985353449&psc=1
#
# ## Capítulo 1 - Sistemas de Equações Lineares
#
# <blockquote> Soluções em Python by João Garbini </blockquote>

# %%
#importando o sympy e definindo a funçã opara imorimir em um formato mais amigável

from sympy import *

init_printing(pretty_print=true)

# %%
#definindo as variáveis x, y e z como símbolos
x , y, z = symbols('x y z')

# %% [markdown]
# Exemplo 4- Resolva e represente graficamente cada sistema de equações lineares.
#
#  a) x + y = 3        b) x + y = 3         c) x + y = 3
#     x - y = -1          2x + 2y = 6          x + y = 1

# %%
# a)
solve([x + y - 3, x -y +1],[x,y])
# Out:
# {x: 1, y: 2}

# %%
# b) Esse sitema possui infinitas soluções onde o y pode ser qualquer número real
solve([x + y - 3, 2*x + 2*y -6],[x,y])
# Out:
# {x: 3 - y}

# %%
#c) Esse sistema não possui nenhuma solução pois a soma de dois números não pode ser 3 e 1 simultaneamente
solve([x +y -3, x + y -1],[x,y])
# Out:
# []

# %% [markdown]
# Abaixo temos os gráficos dos 3 sistemas, essas são imagens originais retiradas do livro do Ron Larson

# %% [markdown]
# ![Ron%20Larson%20-%20Elementos%20De%20%C3%81lgebra%20Linear-Cengage%20Learning%20%282017%29.pdf%20-%20Adobe%20Acrobat%20Reader%20DC.jpg](attachment:Ron%20Larson%20-%20Elementos%20De%20%C3%81lgebra%20Linear-Cengage%20Learning%20%282017%29.pdf%20-%20Adobe%20Acrobat%20Reader%20DC.jpg)

# %%
# Importando o pacote matplotlib e o pylab para reproduzirmos os gráficos da imagem
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import plot, arange

# %%
#Gráfico do sistema a) o ponto de intersecção das retas é exatamente a solução do sistema x=1, y=2 
x = arange(-1,4,1)
y=3-x
y1=1+x
plot(x,y)
plot(x,y1)
plt.grid(True)
plt.xlabel("Abscissas")
plt.ylabel("Ordenadas")
# Out:
# Text(0, 0.5, 'Ordenadas')

# %%
# Gráfico do sistema b) as duas reatas são coincidentes uma sobre a outra e diferente do gráfico anterior onde tinhamos apenas
#um ponto de intersecção aqui teremos infinitos pontos de intersecção
x = arange(-1,4,1)
y=3-x
y1=3-x
plot(x,y)
plot(x,y1,'k:', color='red')

plt.xlabel("Abscissas")
plt.ylabel("Ordenadas")
# Out:
# Text(0, 0.5, 'Ordenadas')

# %%
#Gráfico do sistema c) sendo as retas paralelas nunca teremos ponto de intersecção, indicando que não há solução para o sistema
x = arange(-1,4,1)
y=3-x
y1=1-x
plot(x,y)
plot(x,y1)
plt.grid(True)
plt.xlabel("Abscissas")
plt.ylabel("Ordenadas")
# Out:
# Text(0, 0.5, 'Ordenadas')

# %% [markdown]
# _______________________________________________________________________________________________________________________________
#
#
#
#
# Exemplo 7 Resolva o Sistema
#
# x - 2y + 3z =  9
# -x + 3y     = -4
# 2x - 5y +5z = 17

# %%
solve([ x -2*y + 3 *z-9, -x + 3*y +4,2*x-5*y+5*z-17],[x,y,z])
# Out:
# {x: 1, y: -1, z: 2}

# %% [markdown]
# Exercícios 1.1
#
# Análise gráfica Nos Exercícios 11-24, represente graficamente o sistema de equações lineares. Resolva o sistema e interprete sua resposta.
#
#
# 11. 2x + y = 4 'Retas se cruzam indicando apenas uma solução'
#     x - y = 2
#
#
# 13. -x + y = 1 'Retas paralelas sem solução
#     3x -3y = 4
#
#
# 15. 2x + y = 9 'Retas se cruzam indicando apenas uma solução'
#     3x -5y = 7

# %%
#11 
solve([2*x+y-4, x -y -2],[x,y])
# Out:
# {x: 2, y: 0}

# %%
x = arange(-1,4,1)
y=4-2*x
y1=-2+x
plot(x,y)
plot(x,y1)
plt.grid(True)
plt.xlabel("Abscissas")
plt.ylabel("Ordenadas")
# Out:
# Text(0, 0.5, 'Ordenadas')

# %%
#13 
solve([-x+y-1, 3*x -3*y -4],[x,y])
# Out:
# []

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import plot, arange
x = arange(-1,4,1)
y=1+x
y1=(-4/3+(3*x)/3)
plot(x,y)
plot(x,y1)
plt.grid(True)
plt.xlabel("Abscissas")
plt.ylabel("Ordenadas")
# Out:
# Text(0, 0.5, 'Ordenadas')

# %%
#definindo as variáveis x, y e z como símbolos
x , y, z = symbols('x y z')


solve([2*x+y-9,3*x-5*y-7],[x,y])
# Out:
# {x: 4, y: 1}

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import plot, arange
x = arange(-1,7,1)
y=9-2*x
y1=(-7/5+(3*x)/5)
plot(x,y)
plot(x,y1)
plt.grid(True)
plt.xlabel("Abscissas")
plt.ylabel("Ordenadas")
# Out:
# Text(0, 0.5, 'Ordenadas')
